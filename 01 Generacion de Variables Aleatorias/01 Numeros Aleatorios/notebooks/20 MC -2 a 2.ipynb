# %%
import numpy as np

# %%
k = 1000
a = -2
b = 2

# %%
def h(u):
    return (b-a)*np.exp(a+(b-a)*u + (a+(b-a)*u))

# %%
u = np.random.random(k)

# %%
u
# Out:
# array([0.58943737, 0.47594945, 0.43142988, 0.29589177, 0.40645013,
#        0.52568239, 0.75942777, 0.1731847 , 0.23289845, 0.8279392 ,
#        0.65577639, 0.14730949, 0.34629262, 0.29551511, 0.49410401,
#        0.45427938, 0.73915674, 0.82945721, 0.03372622, 0.92610011,
#        0.20700402, 0.41780478, 0.19468021, 0.02656494, 0.2343373 ,
#        0.02111985, 0.32285792, 0.6295702 , 0.10351126, 0.70769012,
#        0.14363483, 0.47553467, 0.11585631, 0.19115084, 0.7500861 ,
#        0.41414832, 0.4675609 , 0.88852965, 0.86981008, 0.63432962,
#        0.49944362, 0.90650595, 0.71674205, 0.35324965, 0.89119479,
#        0.44354   , 0.04264047, 0.26396549, 0.16703489, 0.85295777,
#        0.02235389, 0.68202502, 0.94500414, 0.57208337, 0.78903302,
#        0.89212725, 0.05372866, 0.2842059 , 0.3186565 , 0.86968494,
#        0.70100135, 0.03820081, 0.57565547, 0.44232038, 0.68417687,
#        0.4269376 , 0.86363555, 0.35832874, 0.70860783, 0.84181725,
# ...

# %%
h(u)
# Out:
# array([8.18082780e+00, 3.29989281e+00, 2.31112272e+00, 7.81475488e-01,
#        1.89249369e+00, 4.91235528e+00, 3.18716381e+01, 2.92810975e-01,
#        4.72121914e-01, 5.51362822e+01, 1.39085745e+01, 2.38060677e-01,
#        1.16956901e+00, 7.79124211e-01, 3.81570881e+00, 2.77466320e+00,
#        2.71003947e+01, 5.58099445e+01, 9.59530902e-02, 1.20915900e+02,
#        3.83784740e-01, 2.07245234e+00, 3.47752592e-01, 9.06104159e-02,
#        4.77587806e-01, 8.67480939e-02, 9.69628468e-01, 1.12780232e+01,
#        1.67693808e-01, 2.10692647e+01, 2.31164194e-01, 3.28896108e+00,
#        1.85100720e-01, 3.38071142e-01, 2.95765908e+01, 2.01270762e+00,
#        3.08570925e+00, 8.95262187e+01, 7.70746937e+01, 1.17157179e+01,
#        3.98223547e+00, 1.03372811e+02, 2.26516067e+01, 1.23650830e+00,
#        9.14555130e+01, 2.54623140e+00, 1.03045783e-01, 6.05329897e-01,
#        2.78753752e-01, 6.73536123e+01, 8.76087417e-02, 1.71585145e+01,
# ...

# %%
h(u).mean()
# Out:
# np.float64(26.12600068341872)
